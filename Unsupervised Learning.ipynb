# %%
import numpy as np

import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('Iris.csv')
x = df.iloc[:,[1,2,3,4]].values

# %%
sumofsquares = []
for i in range(1,11):
    kmeans = KMeans(n_clusters = i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(x)
    sumofsquares.append(kmeans.inertia_)
    

plt.plot(range(1,11), sumofsquares)
plt.title('the elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('within clusters sum of squares')
plt.show()

# %%
# we apply k-means. The number of clusters would be where the
#elbow occurs - 3

# %%
kmeans = KMeans(n_clusters = 3, init='k-means++', max_iter=300, n_init=10, random_state=0)
y_kmeans = kmeans.fit_predict(x)

# %%
plt.scatter(x[y_kmeans==0,0], x[y_kmeans==0,1], s=100, c='red', label = 'Iris-Setosa')
plt.scatter(x[y_kmeans==1,0], x[y_kmeans==1,1], s=100, c='blue', label = 'Iris-Versicolor')
plt.scatter(x[y_kmeans==2,0], x[y_kmeans==2,1], s=100, c='green', label = 'Iris-Virginica')


plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=100, c='yellow', label='Centroids')
plt.legend()

# %% [markdown]
# # Using scikit-learn to perform PCA

# %%
from sklearn.decomposition import PCA

model = PCA()
model.fit(samples)
PCA(copy=True)

# %% [markdown]
# Pearson Correlation:
# 1. Measures linear correlation of features
# 2. value between -1 and 1
# 3. Value of 0 means no correlation.
#
# Principal components:
# 1. principal components = directions of variance.
# 2. PCA aligns principal components with the axes
# 3. Available as components_ attribite of the PCA object
# 4. Each row defines displacement from mean.
# 5. "print(model.components_)"
